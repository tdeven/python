# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0,6])
ypoints = np.array([0,250])
plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,8])
ypoints = np.array([3,10])

plt.plot(xpoints, ypoints , "o")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = ([1,2,6,8])
ypoints = ([3,8,1,10])

plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = ([2,6,1,8,4,9])

plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = ([2,6,1,8,4,9])

plt.plot(ypoints, marker="o")#marker to emphasize each point with a specified marker
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = ([2,6,1,8,4,9])

plt.plot(ypoints, marker="*")#marker to emphasize each point with a specified marker
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = ([3,8,1,10])
plt.plot(ypoints, 'o:r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = ([3,8,1,10])
plt.plot(ypoints, 'o-')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = ([3,8,1,10])
plt.plot(ypoints, 'o:')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = ([3,8,1,10])
plt.plot(ypoints, "o--")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = ([3,8,1,10])
plt.plot(ypoints, "o-.")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = ([3,8,1,10])
plt.plot(ypoints, "o-.g")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = ([3,8,1,10])
plt.plot(ypoints, "o-.m")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = ([3,8,1,10])
plt.plot(ypoints,"o-.g", ms=20)#ms--> markersize= to set the size of the markers.
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoinst = ([1,3,4,5])
plt.plot(xpoints, "o--r", ms = 30, mec = 'r') # mec = markeredgecolor-->to set the color of the edge of the markders = mfc
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoinst = ([1,3,4,5])
plt.plot(xpoints, "o--r", ms = 30, mec = 'r', mfc = "#4CAF50") # mec = markeredgecolor-->to set the color of the edge of the markders = mfc
plt.show()
