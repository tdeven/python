# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A", "B","C", "D"])
y = np.array([3,8,1,10])

plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["APPLES", "BANANA", "ORANGES"])
y = np.array([250,350,150])
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["APPLES", "BANANA", "ORANGES"])
y = np.array([250,350,150])
plt.barh(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["APPLES", "BANANA", "ORANGES"])
y = np.array([250,350,150])
plt.bar(x,y, color = "g")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["APPLES", "BANANA", "ORANGES"])
y = np.array([250,350,150])
plt.bar(x,y,color="hotpink")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["APPLES", "BANANA", "ORANGES"])
y = np.array([250,350,150])
plt.bar(x,y,width = 0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["APPLES", "BANANA", "ORANGES"])
y = np.array([250,350,150])
plt.barh(x,y,height=0.1)
plt.show()
